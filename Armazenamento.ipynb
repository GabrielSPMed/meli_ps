# %%
import json
import psycopg2

# %%
host = "localhost"
dbname = "meli_ps"
user = "gabrielmedeiros"

connection = psycopg2.connect(
    host=host,
    dbname=dbname,
    user=user
)

# %%
cursor = connection.cursor()

# %%
cursor.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';")

# %%
cursor.fetchall()
# Out:
# [('seller',),
#  ('products',),
#  ('address',),
#  ('attributes',),
#  ('shipping',),
#  ('installments',)]

# %%
def insert_seller(cursor, connection, result):
    insert_query = """
        INSERT INTO seller (id, nickname) 
        VALUES (%s, %s)
        ON CONFLICT (id) DO NOTHING;
    """
    seller = result.get('seller')
    data = (seller.get('id'), seller.get('nickname'))
    cursor.execute(insert_query, data)
    connection.commit()
    
def insert_address(cursor, connection, result):
    insert_query = """
        INSERT INTO address (id, state_id, state_name, city_name) 
        VALUES (%s, %s, %s, %s)
        ON CONFLICT (id) DO NOTHING;
    """
    address = result.get('address')
    data = (address.get('city_id'), address.get('state_id'), address.get('state_name'), address.get('city_name'))
    cursor.execute(insert_query, data)
    connection.commit()
    
def insert_shipping(cursor, connection, result, product_id):
    insert_query = """
        INSERT INTO shipping (product_id, store_pick_up, free_shipping, logistic_type, mode, benefits, promise, shipping_score) 
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
        ON CONFLICT (product_id) DO NOTHING;
    """
    shipping = result.get('shipping')
    data = (product_id, shipping.get('store_pick_up'), shipping.get('free_shipping'), shipping.get('logistic_type'),
           shipping.get('mode'), shipping.get('benefits'), shipping.get('promise'), shipping.get('shipping_score'))
    cursor.execute(insert_query, data)
    connection.commit()
    
def insert_product(cursor, connection, result):
    insert_query = """
        INSERT INTO products (
            id, seller_id, city_id, title, condition, thumbnail_id, catalog_product_id, 
            listing_type_id, sanitized_title, permalink, buying_mode, site_id, category_id, 
            domain_id, thumbnail, currency_id, order_backend, price, original_price, 
            sales_price_amount, sales_price_regular_amount, available_quantity, 
            official_store_id, use_thumbnail_id, accepts_mercadopago
        ) 
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, 
                # %s, %s, %s, %s, %s, %s, %s)
        ON CONFLICT (id) DO NOTHING;
    """
    
    seller_id = result.get('seller', {}).get('id') if result.get('seller') else None
    city_id = result.get('address', {}).get('city_id') if result.get('address') else None
    sale_price_amount = result.get('sale_price', {}).get('amount') if result.get('sale_price') else None
    sale_price_regular_amount = result.get('sale_price', {}).get('regular_amount') if result.get('sale_price') else None
    
    data = (
        result.get('id'), 
        seller_id, 
        city_id, 
        result.get('title'), 
        result.get('condition'),
        result.get('thumbnail_id'), 
        result.get('catalog_product_id'), 
        result.get('listing_type_id'),
        result.get('sanitized_title'), 
        result.get('permalink'), 
        result.get('buying_mode'), 
        result.get('site_id'),
        result.get('category_id'), 
        result.get('domain_id'), 
        result.get('thumbnail'), 
        result.get('currency_id'),
        result.get('order_backend'), 
        result.get('price'), 
        result.get('original_price'), 
        sale_price_amount,
        sale_price_regular_amount, 
        result.get('available_quantity'), 
        result.get('official_store_id'),
        result.get('use_thumbnail_id'), 
        result.get('accepts_mercadopago')
    )

    cursor.execute(insert_query, data)
    connection.commit()

def insert_installments(cursor, connection, result, product_id):
    insert_query = """
        INSERT INTO installments (
            product_id, quantity, amount, rate, currency_id
        ) 
        VALUES (%s, %s, %s, %s, %s)
        ON CONFLICT (product_id) DO NOTHING;
    """
    
    installments = result.get('installments')
    
    data = (
        product_id,
        installments.get('quantity'),
        installments.get('amount'),
        installments.get('rate'),
        installments.get('currency_id')
    )
    
    cursor.execute(insert_query, data)
    connection.commit()

# %%
for offset in range(10):
    with open(f'response_data/response_data_{offset}.json', 'r') as file:
        data = json.load(file)
    print(f'Starting file {offset}')
    count = 1
    total = len(data['results'])
    for result in data['results']:
        print(f'Starting result {count}/{total}')
        product_id = result['id']
        try:
            insert_seller(cursor, connection, result)
            insert_address(cursor, connection, result)
            insert_product(cursor, connection, result)
            insert_shipping(cursor, connection, result, product_id)
            insert_installments(cursor, connection, result, product_id)
            print(f'Result {count} successfull')
        except Exception as e:
            connection.rollback()
            print(f'Error on result {count} of file {offset}')
            print(e)
        count += 1
# Out:
# Starting file 0
# Starting result 1/49
# Result 1 successfull
# Starting result 2/49
# Result 2 successfull
# Starting result 3/49
# Result 3 successfull
# Starting result 4/49
# Error on result 4 of file 0
# 'NoneType' object has no attribute 'get'
# Starting result 5/49
# Result 5 successfull
# Starting result 6/49
# Result 6 successfull
# Starting result 7/49
# Result 7 successfull
# Starting result 8/49
# Result 8 successfull
# Starting result 9/49
# Result 9 successfull
# Starting result 10/49
# Result 10 successfull
# Starting result 11/49
# Result 11 successfull
# Starting result 12/49
# Result 12 successfull
# Starting result 13/49
# Result 13 successfull
# Starting result 14/49
# Result 14 successfull
# Starting result 15/49
# Result 15 successfull
# Starting result 16/49
# Result 16 successfull
# Starting result 17/49
# Result 17 successfull
# Starting result 18/49
# Result 18 successfull
# Starting result 19/49
# Result 19 successfull
# Starting result 20/49
# Result 20 successfull
# Starting result 21/49
# Result 21 successfull
# Starting result 22/49
# Result 22 successfull
# Starting result 23/49
# Result 23 successfull
# Starting result 24/49
# Result 24 successfull
# Starting result 25/49
# Result 25 successfull
# Starting result 26/49
# Result 26 successfull
# Starting result 27/49
# Result 27 successfull
# Starting result 28/49
# Result 28 successfull
# Starting result 29/49
# Result 29 successfull
# Starting result 30/49
# Result 30 successfull
# Starting result 31/49
# Result 31 successfull
# Starting result 32/49
# Result 32 successfull
# Starting result 33/49
# Result 33 successfull
# Starting result 34/49
# Result 34 successfull
# Starting result 35/49
# Result 35 successfull
# Starting result 36/49
# Result 36 successfull
# Starting result 37/49
# Result 37 successfull
# Starting result 38/49
# Result 38 successfull
# Starting result 39/49
# Result 39 successfull
# Starting result 40/49
# Result 40 successfull
# Starting result 41/49
# Result 41 successfull
# Starting result 42/49
# Result 42 successfull
# Starting result 43/49
# Result 43 successfull
# Starting result 44/49
# Result 44 successfull
# Starting result 45/49
# Result 45 successfull
# Starting result 46/49
# Result 46 successfull
# Starting result 47/49
# Result 47 successfull
# Starting result 48/49
# Result 48 successfull
# Starting result 49/49
# Result 49 successfull
# Starting file 1
# Starting result 1/50
# Result 1 successfull
# Starting result 2/50
# Error on result 2 of file 1
# 'NoneType' object has no attribute 'get'
# Starting result 3/50
# Result 3 successfull
# Starting result 4/50
# Result 4 successfull
# Starting result 5/50
# Result 5 successfull
# Starting result 6/50
# Result 6 successfull
# Starting result 7/50
# Result 7 successfull
# Starting result 8/50
# Error on result 8 of file 1
# 'NoneType' object has no attribute 'get'
# Starting result 9/50
# Result 9 successfull
# Starting result 10/50
# Result 10 successfull
# Starting result 11/50
# Result 11 successfull
# Starting result 12/50
# Result 12 successfull
# Starting result 13/50
# Result 13 successfull
# Starting result 14/50
# Result 14 successfull
# Starting result 15/50
# Result 15 successfull
# Starting result 16/50
# Result 16 successfull
# Starting result 17/50
# Result 17 successfull
# Starting result 18/50
# Result 18 successfull
# Starting result 19/50
# Result 19 successfull
# Starting result 20/50
# Result 20 successfull
# Starting result 21/50
# Result 21 successfull
# Starting result 22/50
# Result 22 successfull
# Starting result 23/50
# Result 23 successfull
# Starting result 24/50
# Result 24 successfull
# Starting result 25/50
# Result 25 successfull
# Starting result 26/50
# Result 26 successfull
# Starting result 27/50
# Result 27 successfull
# Starting result 28/50
# Result 28 successfull
# Starting result 29/50
# Error on result 29 of file 1
# 'NoneType' object has no attribute 'get'
# Starting result 30/50
# Result 30 successfull
# Starting result 31/50
# Result 31 successfull
# Starting result 32/50
# Result 32 successfull
# Starting result 33/50
# Result 33 successfull
# Starting result 34/50
# Result 34 successfull
# Starting result 35/50
# Result 35 successfull
# Starting result 36/50
# Result 36 successfull
# Starting result 37/50
# Result 37 successfull
# Starting result 38/50
# Result 38 successfull
# Starting result 39/50
# Result 39 successfull
# Starting result 40/50
# Result 40 successfull
# Starting result 41/50
# Result 41 successfull
# Starting result 42/50
# Result 42 successfull
# Starting result 43/50
# Result 43 successfull
# Starting result 44/50
# Result 44 successfull
# Starting result 45/50
# Error on result 45 of file 1
# 'NoneType' object has no attribute 'get'
# Starting result 46/50
# Result 46 successfull
# Starting result 47/50
# Result 47 successfull
# Starting result 48/50
# Result 48 successfull
# Starting result 49/50
# Result 49 successfull
# Starting result 50/50
# Result 50 successfull
# Starting file 2
# Starting result 1/50
# Result 1 successfull
# Starting result 2/50
# Result 2 successfull
# Starting result 3/50
# Result 3 successfull
# Starting result 4/50
# Result 4 successfull
# Starting result 5/50
# Result 5 successfull
# Starting result 6/50
# Result 6 successfull
# Starting result 7/50
# Result 7 successfull
# Starting result 8/50
# Result 8 successfull
# Starting result 9/50
# Result 9 successfull
# Starting result 10/50
# Result 10 successfull
# Starting result 11/50
# Result 11 successfull
# Starting result 12/50
# Result 12 successfull
# Starting result 13/50
# Result 13 successfull
# Starting result 14/50
# Result 14 successfull
# Starting result 15/50
# Result 15 successfull
# Starting result 16/50
# Result 16 successfull
# Starting result 17/50
# Result 17 successfull
# Starting result 18/50
# Result 18 successfull
# Starting result 19/50
# Result 19 successfull
# Starting result 20/50
# Result 20 successfull
# Starting result 21/50
# Result 21 successfull
# Starting result 22/50
# Result 22 successfull
# Starting result 23/50
# Result 23 successfull
# Starting result 24/50
# Result 24 successfull
# Starting result 25/50
# Result 25 successfull
# Starting result 26/50
# Result 26 successfull
# Starting result 27/50
# Result 27 successfull
# Starting result 28/50
# Result 28 successfull
# Starting result 29/50
# Result 29 successfull
# Starting result 30/50
# Result 30 successfull
# Starting result 31/50
# Result 31 successfull
# Starting result 32/50
# Result 32 successfull
# Starting result 33/50
# Result 33 successfull
# Starting result 34/50
# Result 34 successfull
# Starting result 35/50
# Result 35 successfull
# Starting result 36/50
# Result 36 successfull
# Starting result 37/50
# Result 37 successfull
# Starting result 38/50
# Result 38 successfull
# Starting result 39/50
# Result 39 successfull
# Starting result 40/50
# Result 40 successfull
# Starting result 41/50
# Result 41 successfull
# Starting result 42/50
# Result 42 successfull
# Starting result 43/50
# Result 43 successfull
# Starting result 44/50
# Result 44 successfull
# Starting result 45/50
# Result 45 successfull
# Starting result 46/50
# Result 46 successfull
# Starting result 47/50
# Result 47 successfull
# Starting result 48/50
# Result 48 successfull
# Starting result 49/50
# Result 49 successfull
# Starting result 50/50
# Result 50 successfull
# Starting file 3
# Starting result 1/49
# Result 1 successfull
# Starting result 2/49
# Result 2 successfull
# Starting result 3/49
# Result 3 successfull
# Starting result 4/49
# Result 4 successfull
# Starting result 5/49
# Result 5 successfull
# Starting result 6/49
# Result 6 successfull
# Starting result 7/49
# Result 7 successfull
# Starting result 8/49
# Result 8 successfull
# Starting result 9/49
# Result 9 successfull
# Starting result 10/49
# Error on result 10 of file 3
# integer out of range
#
# Starting result 11/49
# Result 11 successfull
# Starting result 12/49
# Result 12 successfull
# Starting result 13/49
# Result 13 successfull
# Starting result 14/49
# Result 14 successfull
# Starting result 15/49
# Result 15 successfull
# Starting result 16/49
# Result 16 successfull
# Starting result 17/49
# Result 17 successfull
# Starting result 18/49
# Result 18 successfull
# Starting result 19/49
# Error on result 19 of file 3
# integer out of range
#
# Starting result 20/49
# Result 20 successfull
# Starting result 21/49
# Result 21 successfull
# Starting result 22/49
# Result 22 successfull
# Starting result 23/49
# Result 23 successfull
# Starting result 24/49
# Result 24 successfull
# Starting result 25/49
# Result 25 successfull
# Starting result 26/49
# Result 26 successfull
# Starting result 27/49
# Result 27 successfull
# Starting result 28/49
# Result 28 successfull
# Starting result 29/49
# Result 29 successfull
# Starting result 30/49
# Result 30 successfull
# Starting result 31/49
# Result 31 successfull
# Starting result 32/49
# Result 32 successfull
# Starting result 33/49
# Result 33 successfull
# Starting result 34/49
# Result 34 successfull
# Starting result 35/49
# Result 35 successfull
# Starting result 36/49
# Result 36 successfull
# Starting result 37/49
# Result 37 successfull
# Starting result 38/49
# Result 38 successfull
# Starting result 39/49
# Result 39 successfull
# Starting result 40/49
# Result 40 successfull
# Starting result 41/49
# Result 41 successfull
# Starting result 42/49
# Result 42 successfull
# Starting result 43/49
# Result 43 successfull
# Starting result 44/49
# Result 44 successfull
# Starting result 45/49
# Result 45 successfull
# Starting result 46/49
# Result 46 successfull
# Starting result 47/49
# Error on result 47 of file 3
# integer out of range
#
# Starting result 48/49
# Result 48 successfull
# Starting result 49/49
# Result 49 successfull
# Starting file 4
# Starting result 1/50
# Result 1 successfull
# Starting result 2/50
# Result 2 successfull
# Starting result 3/50
# Result 3 successfull
# Starting result 4/50
# Result 4 successfull
# Starting result 5/50
# Result 5 successfull
# Starting result 6/50
# Result 6 successfull
# Starting result 7/50
# Result 7 successfull
# Starting result 8/50
# Result 8 successfull
# Starting result 9/50
# Result 9 successfull
# Starting result 10/50
# Result 10 successfull
# Starting result 11/50
# Result 11 successfull
# Starting result 12/50
# Result 12 successfull
# Starting result 13/50
# Error on result 13 of file 4
# integer out of range
#
# Starting result 14/50
# Result 14 successfull
# Starting result 15/50
# Result 15 successfull
# Starting result 16/50
# Result 16 successfull
# Starting result 17/50
# Result 17 successfull
# Starting result 18/50
# Result 18 successfull
# Starting result 19/50
# Result 19 successfull
# Starting result 20/50
# Result 20 successfull
# Starting result 21/50
# Result 21 successfull
# Starting result 22/50
# Result 22 successfull
# Starting result 23/50
# Result 23 successfull
# Starting result 24/50
# Result 24 successfull
# Starting result 25/50
# Result 25 successfull
# Starting result 26/50
# Result 26 successfull
# Starting result 27/50
# Result 27 successfull
# Starting result 28/50
# Result 28 successfull
# Starting result 29/50
# Result 29 successfull
# Starting result 30/50
# Result 30 successfull
# Starting result 31/50
# Result 31 successfull
# Starting result 32/50
# Result 32 successfull
# Starting result 33/50
# Result 33 successfull
# Starting result 34/50
# Result 34 successfull
# Starting result 35/50
# Result 35 successfull
# Starting result 36/50
# Error on result 36 of file 4
# integer out of range
#
# Starting result 37/50
# Result 37 successfull
# Starting result 38/50
# Result 38 successfull
# Starting result 39/50
# Result 39 successfull
# Starting result 40/50
# Result 40 successfull
# Starting result 41/50
# Result 41 successfull
# Starting result 42/50
# Result 42 successfull
# Starting result 43/50
# Result 43 successfull
# Starting result 44/50
# Result 44 successfull
# Starting result 45/50
# Result 45 successfull
# Starting result 46/50
# Result 46 successfull
# Starting result 47/50
# Error on result 47 of file 4
# integer out of range
#
# Starting result 48/50
# Result 48 successfull
# Starting result 49/50
# Result 49 successfull
# Starting result 50/50
# Result 50 successfull
# Starting file 5
# Starting result 1/50
# Result 1 successfull
# Starting result 2/50
# Result 2 successfull
# Starting result 3/50
# Result 3 successfull
# Starting result 4/50
# Result 4 successfull
# Starting result 5/50
# Result 5 successfull
# Starting result 6/50
# Result 6 successfull
# Starting result 7/50
# Result 7 successfull
# Starting result 8/50
# Result 8 successfull
# Starting result 9/50
# Result 9 successfull
# Starting result 10/50
# Result 10 successfull
# Starting result 11/50
# Result 11 successfull
# Starting result 12/50
# Result 12 successfull
# Starting result 13/50
# Result 13 successfull
# Starting result 14/50
# Result 14 successfull
# Starting result 15/50
# Result 15 successfull
# Starting result 16/50
# Result 16 successfull
# Starting result 17/50
# Result 17 successfull
# Starting result 18/50
# Result 18 successfull
# Starting result 19/50
# Result 19 successfull
# Starting result 20/50
# Result 20 successfull
# Starting result 21/50
# Result 21 successfull
# Starting result 22/50
# Result 22 successfull
# Starting result 23/50
# Result 23 successfull
# Starting result 24/50
# Result 24 successfull
# Starting result 25/50
# Result 25 successfull
# Starting result 26/50
# Result 26 successfull
# Starting result 27/50
# Result 27 successfull
# Starting result 28/50
# Result 28 successfull
# Starting result 29/50
# Result 29 successfull
# Starting result 30/50
# Result 30 successfull
# Starting result 31/50
# Result 31 successfull
# Starting result 32/50
# Result 32 successfull
# Starting result 33/50
# Result 33 successfull
# Starting result 34/50
# Result 34 successfull
# Starting result 35/50
# Result 35 successfull
# Starting result 36/50
# Result 36 successfull
# Starting result 37/50
# Result 37 successfull
# Starting result 38/50
# Result 38 successfull
# Starting result 39/50
# Result 39 successfull
# Starting result 40/50
# Result 40 successfull
# Starting result 41/50
# Result 41 successfull
# Starting result 42/50
# Result 42 successfull
# Starting result 43/50
# Result 43 successfull
# Starting result 44/50
# Result 44 successfull
# Starting result 45/50
# Result 45 successfull
# Starting result 46/50
# Result 46 successfull
# Starting result 47/50
# Result 47 successfull
# Starting result 48/50
# Result 48 successfull
# Starting result 49/50
# Result 49 successfull
# Starting result 50/50
# Result 50 successfull
# Starting file 6
# Starting result 1/50
# Result 1 successfull
# Starting result 2/50
# Result 2 successfull
# Starting result 3/50
# Result 3 successfull
# Starting result 4/50
# Error on result 4 of file 6
# 'NoneType' object has no attribute 'get'
# Starting result 5/50
# Result 5 successfull
# Starting result 6/50
# Result 6 successfull
# Starting result 7/50
# Result 7 successfull
# Starting result 8/50
# Result 8 successfull
# Starting result 9/50
# Result 9 successfull
# Starting result 10/50
# Result 10 successfull
# Starting result 11/50
# Result 11 successfull
# Starting result 12/50
# Result 12 successfull
# Starting result 13/50
# Error on result 13 of file 6
# 'NoneType' object has no attribute 'get'
# Starting result 14/50
# Result 14 successfull
# Starting result 15/50
# Result 15 successfull
# Starting result 16/50
# Result 16 successfull
# Starting result 17/50
# Result 17 successfull
# Starting result 18/50
# Result 18 successfull
# Starting result 19/50
# Result 19 successfull
# Starting result 20/50
# Result 20 successfull
# Starting result 21/50
# Result 21 successfull
# Starting result 22/50
# Result 22 successfull
# Starting result 23/50
# Result 23 successfull
# Starting result 24/50
# Result 24 successfull
# Starting result 25/50
# Result 25 successfull
# Starting result 26/50
# Result 26 successfull
# Starting result 27/50
# Result 27 successfull
# Starting result 28/50
# Result 28 successfull
# Starting result 29/50
# Result 29 successfull
# Starting result 30/50
# Result 30 successfull
# Starting result 31/50
# Result 31 successfull
# Starting result 32/50
# Result 32 successfull
# Starting result 33/50
# Result 33 successfull
# Starting result 34/50
# Result 34 successfull
# Starting result 35/50
# Result 35 successfull
# Starting result 36/50
# Result 36 successfull
# Starting result 37/50
# Result 37 successfull
# Starting result 38/50
# Result 38 successfull
# Starting result 39/50
# Result 39 successfull
# Starting result 40/50
# Result 40 successfull
# Starting result 41/50
# Error on result 41 of file 6
# 'NoneType' object has no attribute 'get'
# Starting result 42/50
# Result 42 successfull
# Starting result 43/50
# Result 43 successfull
# Starting result 44/50
# Result 44 successfull
# Starting result 45/50
# Result 45 successfull
# Starting result 46/50
# Result 46 successfull
# Starting result 47/50
# Result 47 successfull
# Starting result 48/50
# Result 48 successfull
# Starting result 49/50
# Result 49 successfull
# Starting result 50/50
# Result 50 successfull
# Starting file 7
# Starting result 1/48
# Result 1 successfull
# Starting result 2/48
# Result 2 successfull
# Starting result 3/48
# Result 3 successfull
# Starting result 4/48
# Result 4 successfull
# Starting result 5/48
# Result 5 successfull
# Starting result 6/48
# Result 6 successfull
# Starting result 7/48
# Result 7 successfull
# Starting result 8/48
# Result 8 successfull
# Starting result 9/48
# Result 9 successfull
# Starting result 10/48
# Result 10 successfull
# Starting result 11/48
# Result 11 successfull
# Starting result 12/48
# Result 12 successfull
# Starting result 13/48
# Result 13 successfull
# Starting result 14/48
# Result 14 successfull
# Starting result 15/48
# Result 15 successfull
# Starting result 16/48
# Result 16 successfull
# Starting result 17/48
# Result 17 successfull
# Starting result 18/48
# Result 18 successfull
# Starting result 19/48
# Result 19 successfull
# Starting result 20/48
# Result 20 successfull
# Starting result 21/48
# Result 21 successfull
# Starting result 22/48
# Result 22 successfull
# Starting result 23/48
# Result 23 successfull
# Starting result 24/48
# Result 24 successfull
# Starting result 25/48
# Result 25 successfull
# Starting result 26/48
# Result 26 successfull
# Starting result 27/48
# Result 27 successfull
# Starting result 28/48
# Result 28 successfull
# Starting result 29/48
# Result 29 successfull
# Starting result 30/48
# Error on result 30 of file 7
# 'NoneType' object has no attribute 'get'
# Starting result 31/48
# Result 31 successfull
# Starting result 32/48
# Result 32 successfull
# Starting result 33/48
# Result 33 successfull
# Starting result 34/48
# Result 34 successfull
# Starting result 35/48
# Result 35 successfull
# Starting result 36/48
# Result 36 successfull
# Starting result 37/48
# Result 37 successfull
# Starting result 38/48
# Result 38 successfull
# Starting result 39/48
# Result 39 successfull
# Starting result 40/48
# Result 40 successfull
# Starting result 41/48
# Result 41 successfull
# Starting result 42/48
# Result 42 successfull
# Starting result 43/48
# Result 43 successfull
# Starting result 44/48
# Result 44 successfull
# Starting result 45/48
# Result 45 successfull
# Starting result 46/48
# Result 46 successfull
# Starting result 47/48
# Result 47 successfull
# Starting result 48/48
# Result 48 successfull
# Starting file 8
# Starting result 1/49
# Result 1 successfull
# Starting result 2/49
# Result 2 successfull
# Starting result 3/49
# Result 3 successfull
# Starting result 4/49
# Result 4 successfull
# Starting result 5/49
# Result 5 successfull
# Starting result 6/49
# Result 6 successfull
# Starting result 7/49
# Result 7 successfull
# Starting result 8/49
# Result 8 successfull
# Starting result 9/49
# Result 9 successfull
# Starting result 10/49
# Result 10 successfull
# Starting result 11/49
# Result 11 successfull
# Starting result 12/49
# Error on result 12 of file 8
# 'NoneType' object has no attribute 'get'
# Starting result 13/49
# Result 13 successfull
# Starting result 14/49
# Result 14 successfull
# Starting result 15/49
# Result 15 successfull
# Starting result 16/49
# Result 16 successfull
# Starting result 17/49
# Result 17 successfull
# Starting result 18/49
# Result 18 successfull
# Starting result 19/49
# Error on result 19 of file 8
# 'NoneType' object has no attribute 'get'
# Starting result 20/49
# Result 20 successfull
# Starting result 21/49
# Result 21 successfull
# Starting result 22/49
# Result 22 successfull
# Starting result 23/49
# Result 23 successfull
# Starting result 24/49
# Result 24 successfull
# Starting result 25/49
# Result 25 successfull
# Starting result 26/49
# Result 26 successfull
# Starting result 27/49
# Result 27 successfull
# Starting result 28/49
# Result 28 successfull
# Starting result 29/49
# Result 29 successfull
# Starting result 30/49
# Result 30 successfull
# Starting result 31/49
# Result 31 successfull
# Starting result 32/49
# Result 32 successfull
# Starting result 33/49
# Result 33 successfull
# Starting result 34/49
# Result 34 successfull
# Starting result 35/49
# Result 35 successfull
# Starting result 36/49
# Result 36 successfull
# Starting result 37/49
# Result 37 successfull
# Starting result 38/49
# Result 38 successfull
# Starting result 39/49
# Error on result 39 of file 8
# 'NoneType' object has no attribute 'get'
# Starting result 40/49
# Result 40 successfull
# Starting result 41/49
# Result 41 successfull
# Starting result 42/49
# Result 42 successfull
# Starting result 43/49
# Result 43 successfull
# Starting result 44/49
# Result 44 successfull
# Starting result 45/49
# Result 45 successfull
# Starting result 46/49
# Result 46 successfull
# Starting result 47/49
# Result 47 successfull
# Starting result 48/49
# Result 48 successfull
# Starting result 49/49
# Result 49 successfull
# Starting file 9
# Starting result 1/50
# Result 1 successfull
# Starting result 2/50
# Result 2 successfull
# Starting result 3/50
# Result 3 successfull
# Starting result 4/50
# Result 4 successfull
# Starting result 5/50
# Result 5 successfull
# Starting result 6/50
# Result 6 successfull
# Starting result 7/50
# Result 7 successfull
# Starting result 8/50
# Result 8 successfull
# Starting result 9/50
# Result 9 successfull
# Starting result 10/50
# Result 10 successfull
# Starting result 11/50
# Result 11 successfull
# Starting result 12/50
# Result 12 successfull
# Starting result 13/50
# Result 13 successfull
# Starting result 14/50
# Result 14 successfull
# Starting result 15/50
# Result 15 successfull
# Starting result 16/50
# Result 16 successfull
# Starting result 17/50
# Result 17 successfull
# Starting result 18/50
# Result 18 successfull
# Starting result 19/50
# Result 19 successfull
# Starting result 20/50
# Result 20 successfull
# Starting result 21/50
# Result 21 successfull
# Starting result 22/50
# Result 22 successfull
# Starting result 23/50
# Result 23 successfull
# Starting result 24/50
# Result 24 successfull
# Starting result 25/50
# Result 25 successfull
# Starting result 26/50
# Result 26 successfull
# Starting result 27/50
# Result 27 successfull
# Starting result 28/50
# Result 28 successfull
# Starting result 29/50
# Result 29 successfull
# Starting result 30/50
# Result 30 successfull
# Starting result 31/50
# Result 31 successfull
# Starting result 32/50
# Result 32 successfull
# Starting result 33/50
# Result 33 successfull
# Starting result 34/50
# Result 34 successfull
# Starting result 35/50
# Result 35 successfull
# Starting result 36/50
# Result 36 successfull
# Starting result 37/50
# Result 37 successfull
# Starting result 38/50
# Result 38 successfull
# Starting result 39/50
# Result 39 successfull
# Starting result 40/50
# Result 40 successfull
# Starting result 41/50
# Result 41 successfull
# Starting result 42/50
# Result 42 successfull
# Starting result 43/50
# Result 43 successfull
# Starting result 44/50
# Result 44 successfull
# Starting result 45/50
# Result 45 successfull
# Starting result 46/50
# Result 46 successfull
# Starting result 47/50
# Result 47 successfull
# Starting result 48/50
# Result 48 successfull
# Starting result 49/50
# Result 49 successfull
# Starting result 50/50
# Result 50 successfull

# %%
cursor.execute("SELECT * FROM address")

# %%
cursor.fetchall()
# Out:
# [('BR-SP-44', 'BR-SP', 'São Paulo', 'São Paulo'),
#  ('TUxCQ0pVSWNlZjAw', 'BR-MG', 'Minas Gerais', 'Juiz de Fora'),
#  ('TUxCQ0VYVDdjZTBi', 'BR-MG', 'Minas Gerais', 'Extrema'),
#  ('BR-SP-42', 'BR-SP', 'São Paulo', 'Campinas'),
#  ('BR-SP-95', 'BR-SP', 'São Paulo', 'Barueri'),
#  ('TUxCQ0xPTmI2Njg1', 'BR-PR', 'Paraná', 'Londrina'),
#  ('BR-SP-11', 'BR-SP', 'São Paulo', 'Itapevi'),
#  ('TUxCQ1BBTGUwMTUw', 'BR-SC', 'Santa Catarina', 'Palhoça'),
#  ('QlItUkpRdWVpbWFkb3M', 'BR-RJ', 'Rio de Janeiro', 'Queimados'),
#  ('BR-SP-23', 'BR-SP', 'São Paulo', 'Ribeirão Preto'),
#  ('QlItU1BQcmVzaWRlbnRlIEVwaXTDoWNpbw',
#   'BR-SP',
#   'São Paulo',
#   'Presidente Epitácio'),
#  ('BR-SP-14', 'BR-SP', 'São Paulo', 'Jundiaí'),
#  ('TUxCQ0JSQTU2M2Yy', 'BR-DF', 'Distrito Federal', 'Brasília'),
#  ('TUxCQ0ZFSWI0MDkz', 'BR-BA', 'Bahia', 'Feira de Santana'),
#  ('QlItU1BDZXJxdWlsaG8', 'BR-SP', 'São Paulo', 'Cerquilho'),
#  ('QlJGcmFuY28gZGEgUm9jaGE', 'BR-SP', 'São Paulo', 'Franco da Rocha'),
#  ('TUxCQ0NBTTZkYzBl', 'BR-SC', 'Santa Catarina', 'Campos Novos'),
#  ('BR-SP-41', 'BR-SP', 'São Paulo', 'Guarulhos'),
#  ('BR-SP-38', 'BR-SP', 'São Paulo', 'Santo André'),
#  ('QlItU1BDYWphbWFy', 'BR-SP', 'São Paulo', 'Cajamar'),
#  ('QlItU1BNaXJhc3NvbA', 'BR-SP', 'São Paulo', 'Mirassol'),
#  ('TUxCQ1BPUjgwZTJl', 'BR-RS', 'Rio Grande do Sul', 'Porto Alegre'),
#  ('TUxCQ0ZPUjM5MmFh', 'BR-CE', 'Ceará', 'Fortaleza'),
#  ('TUxCQ0NBQmQyYjQw', 'BR-PB', 'Paraíba', 'Cabedelo'),
#  ('TUxCQ0NBWDgxMzcw', 'BR-RS', 'Rio Grande do Sul', 'Caxias do Sul'),
#  ('BR-SP-34', 'BR-SP', 'São Paulo', 'Diadema'),
#  ('TUxCQ0lUQTlkMjJj', 'BR-SC', 'Santa Catarina', 'Itajaí'),
#  ('QlItU1BPdXJpbmhvcw', 'BR-SP', 'São Paulo', 'Ourinhos'),
#  ('BR-SP-96', 'BR-SP', 'São Paulo', 'Caraguatatuba'),
#  ('TUxCQ0NVUjYyZmY1', 'BR-PR', 'Paraná', 'Curitiba'),
#  ('BR-SP-29', 'BR-SP', 'São Paulo', 'Sorocaba'),
#  ('TUxCQ0FSQWEyZDQz', 'BR-SE', 'Sergipe', 'Aracaju'),
#  ('BR-SP-92', 'BR-SP', 'São Paulo', 'Santana de Parnaíba'),
#  ('BR-SP-78', 'BR-SP', 'São Paulo', 'Presidente Prudente'),
#  ('TUxCQ0FOQTQ5ZmUz', 'BR-GO', 'Goiás', 'Anápolis'),
#  ('TUxCQ01BUmVmMmFi', 'BR-PR', 'Paraná', 'Maringá'),
#  ('TUxCQ1ZJVGEzZGJj', 'BR-ES', 'Espírito Santo', 'Vitória'),
#  ('QlItU1BBdmFyw6k', 'BR-SP', 'São Paulo', 'Avaré'),
#  ('TUxCQ1ZJTGU5YTdl', 'BR-ES', 'Espírito Santo', 'Vila Velha'),
#  ('TUxCQ0JSVTkxZjAz', 'BR-SC', 'Santa Catarina', 'Brusque'),
#  ('QlItU1BCb3Jib3JlbWE', 'BR-SP', 'São Paulo', 'Borborema'),
#  ('TUxCQ1BJTmU4ZjEw', 'BR-PR', 'Paraná', 'Pinhais'),
#  ('BR-SP-24', 'BR-SP', 'São Paulo', 'Santos'),
#  ('BR-SP-27', 'BR-SP', 'São Paulo', 'São José dos Campos'),
#  ('TUxR29p4m5pYQ', 'BR-GO', 'Goiás', 'Goiânia'),
#  ('TUxCQ0JFTGU0ODdm', 'BR-MG', 'Minas Gerais', 'Belo Horizonte'),
#  ('BR-SP-39', 'BR-SP', 'São Paulo', 'São Bernardo do Campo'),
#  ('TUxCQ1VNVTYyMWMx', 'BR-PR', 'Paraná', 'Umuarama'),
#  ('BR-RJ-01', 'BR-RJ', 'Rio de Janeiro', 'Rio de Janeiro'),
#  ('TUxCQ0lDQTg4MDNh', 'BR-SC', 'Santa Catarina', 'Içara'),
#  ('BR-RJ-05', 'BR-RJ', 'Rio de Janeiro', 'Niterói'),
#  ('TUxCQ0NBTTQ1ZTBl', 'BR-SC', 'Santa Catarina', 'Camboriú'),
#  ('TUxCQ1NBTmVkMjY3', 'BR-MG', 'Minas Gerais', 'Santa Rita do Sapucaí'),
#  ('BR-SP-50', 'BR-SP', 'São Paulo', 'Jacareí'),
#  ('QlItU1BJdMOhcG9saXM', 'BR-SP', 'São Paulo', 'Itápolis'),
#  ('BR-SP-25', 'BR-SP', 'São Paulo', 'São Carlos'),
#  ('QlItU1BCb2l0dXZh', 'BR-SP', 'São Paulo', 'Boituva'),
#  ('TUxCQ1NBT2ViMzg2', 'BR-SC', 'Santa Catarina', 'São José'),
#  ('QlItU1BDZWRyYWw', 'BR-SP', 'São Paulo', 'Cedral'),
#  ('TUxCQ0NBU2NiZTll', 'BR-PR', 'Paraná', 'Cascavel'),
#  ('BR-SP-62', 'BR-SP', 'São Paulo', 'Itu'),
#  ('BR-SP-01', 'BR-SP', 'São Paulo', 'Americana'),
#  ('TUxCQ0RJVmFhZmFi', 'BR-MG', 'Minas Gerais', 'Divinópolis'),
#  ('BR-SP-04', 'BR-SP', 'São Paulo', 'Bauru'),
#  ('TUxCQ1NBUjZmNDhl', 'BR-PR', 'Paraná', 'Sarandi'),
#  ('TUxCQ0JPTTcyMmM2', 'BR-MG', 'Minas Gerais', 'Bom Jesus da Penha'),
#  ('QlItU1BUaWV0w6o', 'BR-SP', 'São Paulo', 'Tietê'),
#  ('TUxCQ05PVjViZWQ1', 'BR-RS', 'Rio Grande do Sul', 'Novo Hamburgo'),
#  ('TUxCQ1NBTzE4YzQ', 'BR-PE', 'Pernambuco', 'São Lourenço da Mata'),
#  ('TUxCQ0pPSTc2NzM4', 'BR-SC', 'Santa Catarina', 'Joinville'),
#  ('QlItU1BUcmVtZW1iw6k', 'BR-SP', 'São Paulo', 'Tremembé'),
#  ('BR-SP-47', 'BR-SP', 'São Paulo', 'Suzano'),
#  ('TUxCQ1ZFUzQzOTg0', 'BR-MG', 'Minas Gerais', 'Vespasiano'),
#  ('BR-SP-15', 'BR-SP', 'São Paulo', 'Limeira'),
#  ('QlItU1BBZ3Vkb3M', 'BR-SP', 'São Paulo', 'Agudos'),
#  ('BR-SP-94', 'BR-SP', 'São Paulo', 'Guarujá'),
#  ('BR-SP-30', 'BR-SP', 'São Paulo', 'Taubaté'),
#  ('BR-SP-99', 'BR-SP', 'São Paulo', 'Espírito Santo do Pinhal'),
#  ('BR-SP-22', 'BR-SP', 'São Paulo', 'Praia Grande'),
#  ('TUxCQ0JMVWM2MDMx', 'BR-SC', 'Santa Catarina', 'Blumenau'),
#  ('TUxCQ0xBRzczMjcw', 'BR-SC', 'Santa Catarina', 'Lages'),
#  ('VVMtRkxNaWFtaQ', 'US-FL', 'Florida', 'Miami'),
#  ('TUxCQ0pBUjg4ZWNi', 'BR-PR', 'Paraná', 'Jardim Alegre'),
#  ('QlJJdGFwZWNlcmljYSBkYSBTZXJyYQ',
#   'BR-SP',
#   'São Paulo',
#   'Itapecerica da Serra'),
#  ('Q04tR0RTaGVuemhlbg', 'CN-GD', 'Guangdong', 'Shenzhen'),
#  ('QlItU1BMZW7Dp8OzaXMgUGF1bGlzdGE', 'BR-SP', 'São Paulo', 'Lençóis Paulista'),
#  ('TUxCQ1hBWDk2NDAz', 'BR-SC', 'Santa Catarina', 'Xaxim'),
#  ('TUxCQ0dVQWEyZDFk', 'BR-PR', 'Paraná', 'Guarapuava'),
#  ('TUxCQ0NPTjMxMzZk', 'BR-MG', 'Minas Gerais', 'Contagem'),
#  ('QlItU1BCYXJyZXRvcw', 'BR-SP', 'São Paulo', 'Barretos'),
#  ('TUxCQ0xFQTllYjlj', 'BR-MG', 'Minas Gerais', 'Leandro Ferreira'),
#  ('QlItU1BGcmFuY2lzY28gTW9yYXRv', 'BR-SP', 'São Paulo', 'Francisco Morato'),
#  ('TUxCQ0NBTTQxMGY2', 'BR-SC', 'Santa Catarina', 'Campo Erê'),
#  ('BR-SP-33', 'BR-SP', 'São Paulo', 'Mogi das Cruzes'),
#  ('TUxCQ0ZBUmMxZDA3', 'BR-RS', 'Rio Grande do Sul', 'Farroupilha'),
#  ('TUxCQ0NSVTVhNTc', 'BR-BA', 'Bahia', 'Cruz das Almas'),
#  ('BR-SP-05', 'BR-SP', 'São Paulo', 'Catanduva'),
#  ('TUxCQ1JFQzM2M2M', 'BR-PE', 'Pernambuco', 'Recife'),
#  ('Q04tSEFTaGFuZ3FpdQ', 'CN-HA', 'Henan', 'Shangqiu')]
